# %% [markdown]
# # TOUR DE FRANCE

# %%
import pandas as pd

# %% [markdown]
# ## STAGES

# %%
stages = pd.read_csv("k-tdf_stages.csv")

# %%
stages.head()
# Out:
#   Stage        Date  Distance             Origin  \
# 0     1  2017-07-01      14.0         Düsseldorf
# 1     2  2017-07-02     203.5         Düsseldorf
# 2     3  2017-07-03     212.5           Verviers
# 3     4  2017-07-04     207.5  Mondorf-les-Bains
# 4     5  2017-07-05     160.5             Vittel
#
#                     Destination                   Type          Winner  \
# 0                    Düsseldorf  Individual time trial  Geraint Thomas
# 1                         Liège             Flat stage   Marcel Kittel
# 2                        Longwy  Medium mountain stage     Peter Sagan
# 3                        Vittel             Flat stage   Arnaud Démare
# 4  La Planche des Belles Filles  Medium mountain stage       Fabio Aru
#
#   Winner_Country
# 0            GBR
# 1            GER
# 2            SVK
# 3            FRA
# 4            ITA

# %%
# DISTANCE REPRESENTS THE LENGTH OF THE STAGE IN KM

stages["Distance"].describe()
# Out:
# count    2236.000000
# mean      196.782994
# std        90.176385
# min         1.000000
# 25%       156.000000
# 50%       199.000000
# 75%       236.000000
# max       482.000000
# Name: Distance, dtype: float64

# %%
# MOST OF THE SUPER SHORT STAGES APPEAR TO BE TIME TRIALS

stages[stages["Distance"] > 5].sort_values(by="Distance", ascending=False).tail(5)
# Out:
#      Stage       Date  Distance       Origin  Destination  \
# 641      P 1987-07-01     6.000  West Berlin  West Berlin
# 940      P 1975-06-26     6.000    Charleroi    Charleroi
# 1150    1a 1967-06-29     5.775       Angers       Angers
# 399      P 1998-07-11     5.600       Dublin       Dublin
# 551      P 1991-07-06     5.400         Lyon         Lyon
#
#                        Type                 Winner Winner_Country  \
# 641   Individual time trial           Jelle Nijdam            NED
# 940   Individual time trial        Francesco Moser            ITA
# 1150  Individual time trial  José-Maria Errandonea            ESP
# 399   Individual time trial         Chris Boardman            GBR
# 551   Individual time trial          Thierry Marie            FRA
#
#                      Combined  Year
# 641   West Berlin-West Berlin  1987
# 940       Charleroi-Charleroi  1975
# 1150            Angers-Angers  1967
# 399             Dublin-Dublin  1998
# 551                 Lyon-Lyon  1991

# %% [markdown]
# ### TYPES OF STAGES

# %%
# WHAT IS A PLAIN STAGE? 
# PLAIN STAGES ARE FLAT

stages["Type"].value_counts()
# Out:
# Plain stage                      1053
# Stage with mountain(s)            530
# Individual time trial             205
# Flat stage                        110
# Team time trial                    87
# Hilly stage                        76
# High mountain stage                43
# Mountain stage                     40
# Medium mountain stage              33
# Mountain time trial                13
# Stage with mountain                11
# Mountain Stage                     11
# Flat Stage                          9
# Half Stage                          5
# Transition stage                    4
# Intermediate stage                  3
# Flat cobblestone stage              2
# Plain stage with cobblestones       1
# Name: Type, dtype: int64

# %%
stages["Date"] = pd.to_datetime(stages["Date"])
stages["Year"] = pd.DatetimeIndex(stages["Date"]).year

# %%
stages.head(1)
# Out:
#   Stage       Date  Distance      Origin Destination                   Type  \
# 0     1 2017-07-01      14.0  Düsseldorf  Düsseldorf  Individual time trial
#
#            Winner Winner_Country               Combined  Year
# 0  Geraint Thomas            GBR  Düsseldorf-Düsseldorf  2017

# %% [markdown]
# ### STAGES BY TYPE BY YEAR

# %%
stages.groupby("Year")["Type"].value_counts()
# Out:
# Year  Type
# 1903  Plain stage               5
#       Stage with mountain(s)    1
# 1904  Plain stage               5
#       Stage with mountain(s)    1
# 1905  Plain stage               9
#                                ..
# 2016  Mountain time trial       1
# 2017  Flat stage                8
#       Medium mountain stage     6
#       High mountain stage       5
#       Individual time trial     2
# Name: Type, Length: 391, dtype: int64

# %%
# SIMPLIFY THE VARIOUS STAGE TYPES INTO THEIR MODERN-ERA EQUIVALENTS

stages.loc[stages["Type"] == "Plain stage", "Type_Adjusted"] = "Flat"
stages.loc[stages["Type"] == "Stage with mountain(s)", "Type_Adjusted"] = "Mountain"
stages.loc[stages["Type"] == "Individual time trial", "Type_Adjusted"] = "Flat"
stages.loc[stages["Type"] == "Flat stage", "Type_Adjusted"] = "Flat"
stages.loc[stages["Type"] == "Team time trial", "Type_Adjusted"] = "Flat"
stages.loc[stages["Type"] == "Hilly stage", "Type_Adjusted"] = "Hilly"
stages.loc[stages["Type"] == "High mountain stage", "Type_Adjusted"] = "Mountain"
stages.loc[stages["Type"] == "Mountain stage", "Type_Adjusted"] = "Mountain"
stages.loc[stages["Type"] == "Medium mountain stage", "Type_Adjusted"] = "Mountain"
stages.loc[stages["Type"] == "Mountain time trial", "Type_Adjusted"] = "Mountain"
stages.loc[stages["Type"] == "Stage with mountain", "Type_Adjusted"] = "Mountain"
stages.loc[stages["Type"] == "Mountain Stage", "Type_Adjusted"] = "Mountain"
stages.loc[stages["Type"] == "Flat Stage", "Type_Adjusted"] = "Flat"
stages.loc[stages["Type"] == "Half Stage", "Type_Adjusted"] = "Other"
stages.loc[stages["Type"] == "Transition stage", "Type_Adjusted"] = "Other"
stages.loc[stages["Type"] == "Intermediate stage", "Type_Adjusted"] = "Other"
stages.loc[stages["Type"] == "Flat cobblestone stage", "Type_Adjusted"] = "Flat"
stages.loc[stages["Type"] == "Plain stage with cobblestones", "Type_Adjusted"] = "Flat"

# %%
# COUNT WITH THE NEW CLEANED UP TYPE NAMES

stages.groupby("Year")["Type_Adjusted"].value_counts()
# Out:
# Year  Type_Adjusted
# 1903  Flat              5
#       Mountain          1
# 1904  Flat              5
#       Mountain          1
# 1905  Flat              9
#                        ..
# 2015  Flat              9
# 2016  Mountain         11
#       Flat             10
# 2017  Mountain         11
#       Flat             10
# Name: Type_Adjusted, Length: 238, dtype: int64

# %%
len(stages[(stages["Year"] == 1903) & (stages["Type_Adjusted"] == "Flat")])
# Out:
# 5

# %%
# NUMBER OF STAGES BY YEAR

stages.groupby("Year")["Type_Adjusted"].count()
# Out:
# Year
# 1903     6
# 1904     6
# 1905    11
# 1906    13
# 1907    14
#         ..
# 2013    21
# 2014    21
# 2015    21
# 2016    21
# 2017    21
# Name: Type_Adjusted, Length: 104, dtype: int64

# %%
# GROUP THE YEARS INTO DECADES

stages.loc[(stages["Year"] >= 1900) & (stages["Year"] <= 1909), "Decade"] = "1900s"
stages.loc[(stages["Year"] >= 1910) & (stages["Year"] <= 1919), "Decade"] = "1910s"
stages.loc[(stages["Year"] >= 1920) & (stages["Year"] <= 1929), "Decade"] = "1920s"
stages.loc[(stages["Year"] >= 1930) & (stages["Year"] <= 1939), "Decade"] = "1930s"
stages.loc[(stages["Year"] >= 1940) & (stages["Year"] <= 1949), "Decade"] = "1940s"
stages.loc[(stages["Year"] >= 1950) & (stages["Year"] <= 1959), "Decade"] = "1950s"
stages.loc[(stages["Year"] >= 1960) & (stages["Year"] <= 1969), "Decade"] = "1960s"
stages.loc[(stages["Year"] >= 1970) & (stages["Year"] <= 1979), "Decade"] = "1970s"
stages.loc[(stages["Year"] >= 1980) & (stages["Year"] <= 1989), "Decade"] = "1980s"
stages.loc[(stages["Year"] >= 1990) & (stages["Year"] <= 1999), "Decade"] = "1990s"
stages.loc[(stages["Year"] >= 2000) & (stages["Year"] <= 2009), "Decade"] = "2000s"
stages.loc[(stages["Year"] >= 2010) & (stages["Year"] <= 2019), "Decade"] = "2010s"

# %% [markdown]
# ### TYPES OF STAGE BY DECADE

# %%
stages.groupby("Decade")["Type_Adjusted"].value_counts()
# Out:
# Decade  Type_Adjusted
# 1900s   Flat              60
#         Mountain          18
# 1910s   Flat              50
#         Mountain          40
# 1920s   Flat             126
#         Mountain          52
# 1930s   Flat             175
#         Mountain          80
# 1940s   Flat              44
#         Mountain          19
# 1950s   Flat             151
#         Mountain          81
# 1960s   Flat             162
#         Mountain          80
# 1970s   Flat             171
#         Mountain          80
#         Hilly              7
#         Other              5
# 1980s   Flat             168
#         Mountain          49
#         Hilly             22
# 1990s   Flat             141
#         Mountain          46
#         Hilly             31
# 2000s   Flat             133
#         Mountain          54
#         Hilly             16
#         Other              7
# 2010s   Flat              86
#         Mountain          82
# Name: Type_Adjusted, dtype: int64

# %%
stages[stages["Year"] == 1903]
# Out:
#      Stage       Date  Distance     Origin Destination  \
# 2230     1 1903-07-01     467.0      Paris        Lyon
# 2231     2 1903-07-05     374.0       Lyon   Marseille
# 2232     3 1903-07-08     423.0  Marseille    Toulouse
# 2233     4 1903-07-12     268.0   Toulouse    Bordeaux
# 2234     5 1903-07-13     425.0   Bordeaux      Nantes
# 2235     6 1903-07-18     471.0     Nantes       Paris
#
#                         Type                 Winner Winner_Country  \
# 2230             Plain stage          Maurice Garin            FRA
# 2231  Stage with mountain(s)  Hippolyte Aucouturier            FRA
# 2232             Plain stage  Hippolyte Aucouturier            FRA
# 2233             Plain stage         Charles Laeser            SUI
# 2234             Plain stage          Maurice Garin            FRA
# 2235             Plain stage          Maurice Garin            FRA
#
#                 Combined  Year
# 2230          Paris-Lyon  1903
# 2231      Lyon-Marseille  1903
# 2232  Marseille-Toulouse  1903
# 2233   Toulouse-Bordeaux  1903
# 2234     Bordeaux-Nantes  1903
# 2235        Nantes-Paris  1903

# %%
stages["Year"].value_counts().sort_values(ascending=True)
# Out:
# 1903     6
# 1904     6
# 1905    11
# 1906    13
# 1907    14
#         ..
# 1977    28
# 1939    28
# 1938    29
# 1970    29
# 1937    31
# Name: Year, Length: 104, dtype: int64

# %% [markdown]
# #### LOWEST NUMBER OF STAGES IN THE TOUR

# %%
stages["Year"].value_counts().sort_values(ascending=True).min()
# Out:
# 6

# %% [markdown]
# #### HIGHEST NUMBER OF STAGES IN THE TOUR

# %%
stages["Year"].value_counts().sort_values(ascending=True).max()
# Out:
# 31

# %% [markdown]
# ### TOUR DISTANCE BY YEAR

# %%
stages.groupby("Year")["Distance"].sum()
# Out:
# Year
# 1903    2428.0
# 1904    2429.0
# 1905    3021.0
# 1906    4543.0
# 1907    4488.0
#          ...
# 2013    3403.5
# 2014    3660.5
# 2015    3360.3
# 2016    3529.0
# 2017    3540.0
# Name: Distance, Length: 104, dtype: float64

# %% [markdown]
# #### SHORTEST TOUR IN KM

# %%
stages.groupby("Year")["Distance"].sum().min()
# Out:
# 2428.0

# %% [markdown]
# #### LONGEST TOUR IN KM

# %%
stages.groupby("Year")["Distance"].sum().max()
# Out:
# 5745.0

# %% [markdown]
# #### MODERN-ERA TOUR LENGTH (1990-PRESENT)

# %%
stages[stages["Year"] >= 1990].groupby("Year").sum()
# Out:
#       Distance
# Year
# 1990    3403.8
# 1991    3914.4
# 1992    3975.0
# 1993    3714.3
# 1994    3978.7
# 1995    3547.3
# 1996    3764.9
# 1997    3943.8
# 1998    3877.1
# 1999    3690.8
# 2000    3662.5
# 2001    3455.2
# 2002    3277.5
# 2003    3427.5
# 2004    3391.1
# 2005    3592.5
# 2006    3657.1
# 2007    3569.9
# 2008    3559.5
# 2009    3459.5
# 2010    3641.9
# 2011    3430.0
# 2012    3496.9
# 2013    3403.5
# 2014    3660.5
# 2015    3360.3
# 2016    3529.0
# 2017    3540.0

# %%
stages[stages["Year"] >= 1990].groupby("Year").sum().mean()
# Out:
# Distance    3604.446429
# dtype: float64

# %% [markdown]
# ### MODERN-ERA TOUR DE FRANCE LENGTH

# %%
stages[stages["Year"] >= 1990].groupby("Year").sum().median()
# Out:
# Distance    3564.7
# dtype: float64

# %%
stages[stages["Year"] >= 1990]["Distance"].median()
# Out:
# 187.0

# %%
stages[stages["Year"] >= 1990]["Distance"].mean()
# Out:
# 169.33640939597316

# %% [markdown]
# ### STAGE START AND FINISH LOCATIONS

# %%
# THE NUMBER REPRESENTS THE TIMES THE LOCATION HAS BEEN FEATURED IN THE TOUR
# IT DOES NOT MEAN THAT THE VERY FIRST STAGE OF THE TOUR STARTS FROM PAU

stages["Origin"].value_counts()
# Out:
# Pau                 62
# Bordeaux            56
# Luchon              51
# Paris               44
# Grenoble            40
#                     ..
# Saint-Gervais        1
# Cap d'Agde           1
# Girona               1
# Andorra la Vella     1
# Douai                1
# Name: Origin, Length: 591, dtype: int64

# %%
stages["Destination"].value_counts().head(10)
# Out:
# Paris        108
# Bordeaux      79
# Pau           60
# Luchon        43
# Metz          38
# Grenoble      35
# Nice          35
# Marseille     35
# Perpignan     35
# Caen          33
# Name: Destination, dtype: int64

# %% [markdown]
# #### MOST COMMON STAGES IN THE TOUR

# %%
stages["Combined"] = stages["Origin"] + "-" + stages["Destination"]
stages["Combined"].value_counts().head(5)
# Out:
# Pau-Bordeaux        18
# Luchon-Perpignan    17
# Strasbourg-Metz     13
# Pau-Luchon          12
# Caen-Paris          12
# Name: Combined, dtype: int64

# %% [markdown]
# #### STAGE WINNERS

# %%
stages["Winner"].value_counts().head(5)
# Out:
# Eddy Merckx        34
# Mark Cavendish     30
# Bernard Hinault    28
# André Leducq       24
# André Darrigade    22
# Name: Winner, dtype: int64

# %% [markdown]
# ## INDIVIDUAL STAGES

# %%
stage = pd.read_csv("k-stage_data.csv")
stage.tail(10)

stage.dtypes
# Out:
# edition               int64
# year                  int64
# stage_results_id     object
# rank                 object
# time                 object
# rider                object
# age                 float64
# team                float64
# points              float64
# elapsed              object
# bib_number           object
# dtype: object

# %% [markdown]
# ## WINNERS

# %%
winners = pd.read_csv("k-tdf_winners.csv")
winners.head(10)
# Out:
#    edition  start_date          winner_name     winner_team  distance  \
# 0        1  1903-07-01        Maurice Garin    La Française    2428.0
# 1        2  1904-07-02         Henri Cornet           Conte    2428.0
# 2        3  1905-07-09    Louis Trousselier  Peugeot–Wolber    2994.0
# 3        4  1906-07-04         René Pottier  Peugeot–Wolber    4637.0
# 4        5  1907-07-08  Lucien Petit-Breton  Peugeot–Wolber    4488.0
# 5        6  1908-07-13  Lucien Petit-Breton  Peugeot–Wolber    4497.0
# 6        7  1909-07-05       François Faber   Alcyon–Dunlop    4498.0
# 7        8  1910-07-01        Octave Lapize   Alcyon–Dunlop    4734.0
# 8        9  1911-07-02     Gustave Garrigou   Alcyon–Dunlop    5343.0
# 9       10  1912-06-30        Odile Defraye   Alcyon–Dunlop    5289.0
#
#    time_overall  time_margin  stage_wins  stages_led  height  weight  age  \
# 0     94.553889     2.989167           3           6    1.62    60.0   32
# 1     96.098611     2.270556           1           3     NaN     NaN   19
# 2           NaN          NaN           5          10     NaN     NaN   24
# 3           NaN          NaN           5          12     NaN     NaN   27
# 4           NaN          NaN           2           5     NaN     NaN   24
# 5           NaN          NaN           5          13     NaN     NaN   25
# 6           NaN          NaN           6          13    1.78    88.0   22
# 7           NaN          NaN           4           3     NaN     NaN   22
# 8           NaN          NaN           2          13     NaN     NaN   26
# 9           NaN          NaN           3          13     NaN     NaN   23
#
#          born        died                 full_name                  nickname  \
# 0  1871-03-03  1957-02-19                       NaN  The Little Chimney-sweep
# 1  1884-08-04  1941-03-18                       NaN     Le rigolo (The joker)
# 2  1881-06-29  1939-04-24                       NaN       Levaloy / Trou-trou
# 3  1879-06-05  1907-01-25                       NaN                       NaN
# 4  1882-10-18  1917-12-20      Lucien Georges Mazan       Lucien Petit-Breton
# 5  1882-10-18  1917-12-20      Lucien Georges Mazan       Lucien Petit-Breton
# 6  1887-01-26  1915-05-09                       NaN     The giant of colombes
# 7  1887-10-24  1917-07-14                       NaN                       NaN
# 8  1884-09-24  1963-01-28  Cyprien Gustave Garrigou                       NaN
# 9  1888-07-14  1965-08-21                       NaN                       NaN
#
#         birth_town birth_country  nationality
# 0           Arvier         Italy       France
# 1          Desvres        France       France
# 2            Paris        France       France
# 3  Moret-sur-Loing        France       France
# 4           Plessé        France       France
# 5           Plessé        France       France
# 6  Aulnay-sur-Iton        France   Luxembourg
# 7            Paris        France       France
# 8           Vabres        France       France
# 9          Rumbeke       Belgium      Belgium

# %% [markdown]
# #### SPEED IN KM/H

# %%
# TIME OVERALL = TIME IN HOURS TO COMPLETE THE RACE
# SPEED = DISTANCE / TIME

winners["speed"] = (winners["distance"] / winners["time_overall"]).dropna()

# %% [markdown]
# #### AVERAGE SPEED OF A WINNING RIDER

# %%
winners["speed"].dropna().mean()
# Out:
# 34.77715143473631

# %% [markdown]
# #### MEDIAN SPEED

# %%
winners["speed"].dropna().median()
# Out:
# 35.88429203655315

# %% [markdown]
# #### MEDIAN WEIGHT OF RIDER IN KILOGRAMS

# %%
winners["weight"].dropna().median()
# Out:
# 69.0

# %%
# CONVERT KILOGRAMS TO LBS BY MULTIPLYING BY 2.2

winners["weight_lbs"] = winners["weight"].dropna() * 2.2
winners["weight_lbs"].median()
# Out:
# 151.8

# %% [markdown]
# #### MEDIAN HEIGHT OF RIDERS IN METERS

# %%
# MEDIAN HEIGHT OF RIDERS IN METERS

winners["height"].dropna().median()
# Out:
# 1.77

# %% [markdown]
# #### RIDER BMI

# %%
# WEIGHT / HEIGHT^2

winners["weight"].dropna() / (winners["height"].dropna() * winners["height"].dropna())
# Out:
# 0      22.862369
# 6      27.774271
# 31     22.309356
# 33     23.147255
# 34     22.309356
#          ...
# 101    19.944502
# 102    19.944502
# 103    19.944502
# 104    21.200991
# 105    19.591837
# Length: 67, dtype: float64

# %% [markdown]
# #### YOUNGEST TOUR WINNER

# %%
# NEED TO MERGE RECENT YEARS 2020-PRESENT FOR WINNERS NOT PRESENT IN ORIGINAL DATSET

winners.sort_values(by="age", ascending=False).tail(5)
# Out:
#      edition  start_date     winner_name    winner_team  distance  \
# 7          8  1910-07-01   Octave Lapize  Alcyon–Dunlop    4734.0
# 6          7  1909-07-05  François Faber  Alcyon–Dunlop    4498.0
# 51        52  1965-06-22  Felice Gimondi      Salvarani    4188.0
# 105      106  2019-07-06     Egan Bernal     Team Ineos    3349.0
# 1          2  1904-07-02    Henri Cornet          Conte    2428.0
#
#      time_overall  time_margin  stage_wins  stages_led  height  weight  age  \
# 7             NaN          NaN           4           3     NaN     NaN   22
# 6             NaN          NaN           6          13    1.78    88.0   22
# 51     116.701667     0.033889           3          18    1.81    71.0   22
# 105     82.950000     0.016944           0           2    1.75    60.0   22
# 1       96.098611     2.270556           1           3     NaN     NaN   19
#
#            born        died                full_name               nickname  \
# 7    1887-10-24  1917-07-14                      NaN                    NaN
# 6    1887-01-26  1915-05-09                      NaN  The giant of colombes
# 51   1942-09-29  2019-08-16                      NaN            The Phoenix
# 105  1997-01-13         NaN  Egan Arley Bernal Gómez                    NaN
# 1    1884-08-04  1941-03-18                      NaN  Le rigolo (The joker)
#
#           birth_town birth_country  nationality  weight_lbs
# 7              Paris        France       France         NaN
# 6    Aulnay-sur-Iton        France   Luxembourg       193.6
# 51           Sedrina         Italy        Italy       156.2
# 105           Bogotá      Columbia     Colombia       132.0
# 1            Desvres        France       France         NaN

# %%
winners["start_date"] = pd.to_datetime(winners["start_date"])

# %%
import datetime

# %%
winners["year"] = pd.DatetimeIndex(winners['start_date']).year

# %%
winners["year"]
# Out:
# 0      1903
# 1      1904
# 2      1905
# 3      1906
# 4      1907
#        ...
# 101    2015
# 102    2016
# 103    2017
# 104    2018
# 105    2019
# Name: year, Length: 106, dtype: int64

# %% [markdown]
# #### WINNING SPEED IN 1903

# %%
speed_1903 = winners[winners["year"] == 1903]["distance"][0] / winners[winners["year"] == 1903]["time_overall"][0]

# %% [markdown]
# #### WINNING SPEED IN 2019

# %%
speed_2019 = winners[winners["year"] == 2019]["distance"][105] / winners[winners["year"] == 2019]["time_overall"][105]

# %%
# ROUGHLY 15 KM/H DIFFERENCE IN SPEED BETWEEN 1903 AND 2019

diff = speed_2019 - speed_1903
diff
# Out:
# 14.695240638828121

# %%
# CALCULATE PERCENT CHANGE USING ((V2-V1) / V1) * 100
# PCT CHANGE IN SPEED, NEARLY 60% INCREASE

((speed_2019 - speed_1903) / speed_1903) * 100
# Out:
# 57.227848046097144

# %%
winners.loc[(winners["year"] >= 1900) & (winners["year"] <= 1909), "decade"] = "1900s"
winners.loc[(winners["year"] >= 1910) & (winners["year"] <= 1919), "decade"] = "1910s"
winners.loc[(winners["year"] >= 1920) & (winners["year"] <= 1929), "decade"] = "1920s"
winners.loc[(winners["year"] >= 1930) & (winners["year"] <= 1939), "decade"] = "1930s"
winners.loc[(winners["year"] >= 1940) & (winners["year"] <= 1949), "decade"] = "1940s"
winners.loc[(winners["year"] >= 1950) & (winners["year"] <= 1959), "decade"] = "1950s"
winners.loc[(winners["year"] >= 1960) & (winners["year"] <= 1969), "decade"] = "1960s"
winners.loc[(winners["year"] >= 1970) & (winners["year"] <= 1979), "decade"] = "1970s"
winners.loc[(winners["year"] >= 1980) & (winners["year"] <= 1989), "decade"] = "1980s"
winners.loc[(winners["year"] >= 1990) & (winners["year"] <= 1999), "decade"] = "1990s"
winners.loc[(winners["year"] >= 2000) & (winners["year"] <= 2009), "decade"] = "2000s"
winners.loc[(winners["year"] >= 2010) & (winners["year"] <= 2019), "decade"] = "2010s"

# %%
winners.tail(50)
# Out:
#      edition start_date       winner_name                     winner_team  \
# 56        57 1970-06-27       Eddy Merckx                   Faemino–Faema
# 57        58 1971-06-26       Eddy Merckx                         Molteni
# 58        59 1972-07-01       Eddy Merckx                         Molteni
# 59        60 1973-06-30        Luis Ocaña                             Bic
# 60        61 1974-06-27       Eddy Merckx                         Molteni
# 61        62 1975-06-26  Bernard Thévenet             Peugeot–BP–Michelin
# 62        63 1976-06-24   Lucien Van Impe               Gitane–Campagnolo
# 63        64 1977-06-30  Bernard Thévenet           Peugeot–Esso–Michelin
# 64        65 1978-06-29   Bernard Hinault       Renault–Gitane–Campagnolo
# 65        66 1979-06-27   Bernard Hinault                  Renault–Gitane
# 66        67 1980-06-26    Joop Zoetemelk                TI–Raleigh–Creda
# 67        68 1981-06-25   Bernard Hinault              Renault–Elf–Gitane
# 68        69 1982-07-02   Bernard Hinault              Renault–Elf–Gitane
# 69        70 1983-07-01    Laurent Fignon                     Renault–Elf
# 70        71 1984-06-29    Laurent Fignon                     Renault–Elf
# 71        72 1985-06-28   Bernard Hinault                   La Vie Claire
# 72        73 1986-07-04       Greg LeMond                   La Vie Claire
# 73        74 1987-07-01     Stephen Roche          Carrera Jeans–Vagabond
# 74        75 1988-07-02     Pedro Delgado                        Reynolds
# 75        76 1989-07-01       Greg LeMond     AD Renting–W-Cup–Bottecchia
# 76        77 1990-06-30       Greg LeMond                       Z–Tomasso
# 77        78 1991-07-06   Miguel Induráin                         Banesto
# 78        79 1992-07-04   Miguel Induráin                         Banesto
# 79        80 1993-07-03   Miguel Induráin                         Banesto
# 80        81 1994-07-02   Miguel Induráin                         Banesto
# 81        82 1995-07-01   Miguel Induráin                         Banesto
# 82        83 1996-06-29       Bjarne Riis                    Team Telekom
# 83        84 1997-07-05       Jan Ullrich                    Team Telekom
# 84        85 1998-07-11     Marco Pantani           Mercatone Uno–Bianchi
# 85        86 1999-07-03   Lance Armstrong             U.S. Postal Service
# 86        87 2000-07-01   Lance Armstrong             U.S. Postal Service
# 87        88 2001-07-07   Lance Armstrong             U.S. Postal Service
# 88        89 2002-07-06   Lance Armstrong             U.S. Postal Service
# 89        90 2003-07-05   Lance Armstrong             U.S. Postal Service
# 90        91 2004-07-03   Lance Armstrong             U.S. Postal Service
# 91        92 2005-07-02   Lance Armstrong               Discovery Channel
# 92        93 2006-07-01     Óscar Pereiro  Caisse d'Epargne–Illes Balears
# 93        94 2007-07-07  Alberto Contador               Discovery Channel
# 94        95 2008-07-05     Carlos Sastre                        Team CSC
# 95        96 2009-07-04  Alberto Contador                          Astana
# 96        97 2010-07-03      Andy Schleck                  Team Saxo Bank
# 97        98 2011-07-02       Cadel Evans                 BMC Racing Team
# 98        99 2012-06-20   Bradley Wiggins                        Team Sky
# 99       100 2013-06-29      Chris Froome                        Team Sky
# 100      101 2014-07-05   Vincenzo Nibali                          Astana
# 101      102 2015-07-04      Chris Froome                        Team Sky
# 102      103 2016-07-02      Chris Froome                        Team Sky
# 103      104 2017-07-01      Chris Froome                        Team Sky
# 104      105 2018-07-07    Geraint Thomas                        Team Sky
# 105      106 2019-07-06       Egan Bernal                      Team Ineos
#
#      distance  time_overall  time_margin  stage_wins  stages_led  height  ...  \
# 56     4254.0    119.530278     0.203333           8          20    1.82  ...
# 57     3608.0     96.753889     0.152500           4          17    1.82  ...
# 58     3846.0    108.288333     0.169444           6          15    1.82  ...
# 59     4090.0    122.426111     0.254167           6          14    1.65  ...
# 60     4098.0    116.282778     0.135556           8          18    1.82  ...
# 61     4000.0    114.591944     0.033889           2           8     NaN  ...
# 62     4017.0    116.373056     0.067778           1          12     NaN  ...
# 63     4096.0    115.641667     0.013333           1           8     NaN  ...
# 64     3908.0    108.300000     0.050833           3           3    1.74  ...
# 65     3765.0    103.113889     0.220278           7          17    1.74  ...
# 66     3842.0    109.320556     0.101667           2          10    1.73  ...
# 67     3753.0     96.327222     0.237222           5          18    1.74  ...
# 68     3507.0     92.146111     0.101667           4          12    1.74  ...
# 69     3809.0    105.131111     0.067778           1           6    1.74  ...
# 70     4021.0    112.061111     0.169444           5           7    1.74  ...
# 71     4109.0    113.406389     0.016944           2          16    1.74  ...
# 72     4094.0    110.588611     0.050833           1           7    1.78  ...
# 73     4231.0    115.461667     0.011111           1           3    1.75  ...
# 74     3286.0     84.464722     0.118611           1          11    1.71  ...
# 75     3285.0     87.643056     0.002222           3           8    1.78  ...
# 76     3504.0     90.722222     0.033889           0           2    1.78  ...
# 77     3914.0    101.022222     0.050833           2          10    1.86  ...
# 78     3983.0    100.825000     0.067778           3          10    1.86  ...
# 79     3714.0     95.952500     0.067778           2          14    1.86  ...
# 80     3978.0    103.643889     0.084722           1          13    1.86  ...
# 81     3635.0     92.749722     0.067778           2          13    1.86  ...
# 82     3765.0     95.954444     0.016944           2          13    1.84  ...
# 83     3950.0    100.509722     0.152500           2          12    1.83  ...
# 84     3875.0     92.829444     0.050833           2           7    1.72  ...
# 85     3687.0     91.537778     0.118611           4          15    1.77  ...
# 86     3662.0     92.552222     0.101667           1          12    1.77  ...
# 87     3458.0     86.291111     0.101667           4           8    1.77  ...
# 88     3272.0     82.086667     0.118611           4          11    1.77  ...
# 89     3427.0     83.686667     0.016944           1          13    1.77  ...
# 90     3391.0     83.600556     0.101667           5           7    1.77  ...
# 91     3593.0     86.250556     0.067778           1          17    1.77  ...
# 92     3657.0     89.674167     0.008889           0           8    1.77  ...
# 93     3570.0     91.007222     0.006389           1           4    1.76  ...
# 94     3559.0     87.881111     0.016111           1           5    1.73  ...
# 95     3459.0     85.809722     0.067778           2           7    1.76  ...
# 96     3642.0     91.990833     0.016944           2          12    1.86  ...
# 97     3430.0     86.206111     0.016944           1           2    1.74  ...
# 98     3496.0     87.579722     0.050833           2          14    1.90  ...
# 99     3404.0     83.938889     0.067778           3          14    1.86  ...
# 100    3660.5     89.985000     0.118611           4          19    1.80  ...
# 101    3360.3     84.770556     0.016944           1          16    1.86  ...
# 102    3529.0     89.080000     0.067778           2          14    1.86  ...
# 103    3540.0     86.348611     0.015000           0          15    1.86  ...
# 104    3349.0     83.286944     0.016944           2          11    1.83  ...
# 105    3349.0     82.950000     0.016944           0           2    1.75  ...
#
#            died                          full_name  \
# 56          NaN        Édouard Louis Joseph Merckx
# 57          NaN        Édouard Louis Joseph Merckx
# 58          NaN        Édouard Louis Joseph Merckx
# 59   1994-06-19            Jesús Luis Ocaña Pernía
# 60          NaN        Édouard Louis Joseph Merckx
# 61          NaN                                NaN
# 62          NaN                                NaN
# 63          NaN                                NaN
# 64          NaN                                NaN
# 65          NaN                                NaN
# 66          NaN  Hendrik Gerardus Joseph Zoetemelk
# 67          NaN                                NaN
# 68          NaN                                NaN
# 69   2010-08-31             Laurent Patrick Fignon
# 70   2010-08-31             Laurent Patrick Fignon
# 71          NaN                                NaN
# 72          NaN               Gregory James LeMond
# 73          NaN                                NaN
# 74          NaN              Pedro Delgado Robledo
# 75          NaN               Gregory James LeMond
# 76          NaN               Gregory James LeMond
# 77          NaN            Miguel Induráin Larraya
# 78          NaN            Miguel Induráin Larraya
# 79          NaN            Miguel Induráin Larraya
# 80          NaN            Miguel Induráin Larraya
# 81          NaN            Miguel Induráin Larraya
# 82          NaN              Bjarne Lykkegård Riis
# 83          NaN                                NaN
# 84   2004-02-14                                NaN
# 85          NaN             Lance Edward Armstrong
# 86          NaN             Lance Edward Armstrong
# 87          NaN             Lance Edward Armstrong
# 88          NaN             Lance Edward Armstrong
# 89          NaN             Lance Edward Armstrong
# 90          NaN             Lance Edward Armstrong
# 91          NaN             Lance Edward Armstrong
# 92          NaN                  Óscar Pereiro Sío
# 93          NaN           Alberto Contador Velasco
# 94          NaN               Carlos Sastre Candil
# 95          NaN           Alberto Contador Velasco
# 96          NaN               Andy Raymond Schleck
# 97          NaN                    Cadel Lee Evans
# 98          NaN               Bradley Marc Wiggins
# 99          NaN           Christopher Clive Froome
# 100         NaN                                NaN
# 101         NaN           Christopher Clive Froome
# 102         NaN           Christopher Clive Froome
# 103         NaN           Christopher Clive Froome
# 104         NaN              Geraint Howell Thomas
# 105         NaN            Egan Arley Bernal Gómez
#
#                                               nickname             birth_town  \
# 56                                        The Cannibal       Meensel-Kiezegem
# 57                                        The Cannibal       Meensel-Kiezegem
# 58                                        The Cannibal       Meensel-Kiezegem
# 59                                                 NaN                 Priego
# 60                                        The Cannibal       Meensel-Kiezegem
# 61                                              Nanard  Saint-Julien-de-Civry
# 62                                  de kleine van Mere                   Mere
# 63                                              Nanard  Saint-Julien-de-Civry
# 64      Le Blaireau (The Badger), Le Patron (The Boss)               Yffiniac
# 65      Le Blaireau (The Badger), Le Patron (The Boss)               Yffiniac
# 66                                                Joop              The Hague
# 67      Le Blaireau (The Badger), Le Patron (The Boss)               Yffiniac
# 68      Le Blaireau (The Badger), Le Patron (The Boss)               Yffiniac
# 69                       Le Professeur (The Professor)                  Paris
# 70                       Le Professeur (The Professor)                  Paris
# 71      Le Blaireau (The Badger), Le Patron (The Boss)               Yffiniac
# 72                              L’Americain, LeMonster               Lakewood
# 73                                                 NaN                Dundrum
# 74                                              Perico                Segovia
# 75                              L’Americain, LeMonster               Lakewood
# 76                              L’Americain, LeMonster               Lakewood
# 77                         Miguelón, Big Mig (English)                Villava
# 78                         Miguelón, Big Mig (English)                Villava
# 79                         Miguelón, Big Mig (English)                Villava
# 80                         Miguelón, Big Mig (English)                Villava
# 81                         Miguelón, Big Mig (English)                Villava
# 82         Ørnen fra Herning\n(The Eagle from Herning)                Herning
# 83            Der Kaiser, Der Jan, Der Junge, The Yoyo                Rostock
# 84   Il Pirata (The pirate), Elefantino (The little...                 Cesena
# 85                                    Le Boss, Big Tex                  Plano
# 86                                    Le Boss, Big Tex                  Plano
# 87                                    Le Boss, Big Tex                  Plano
# 88                                    Le Boss, Big Tex                  Plano
# 89                                    Le Boss, Big Tex                  Plano
# 90                                    Le Boss, Big Tex                  Plano
# 91                                    Le Boss, Big Tex                  Plano
# 92                                                 NaN                    Mos
# 93                                        El Pistolero                  Pinto
# 94                                                 NaN                Leganés
# 95                                        El Pistolero                  Pinto
# 96                                                 NaN        Luxembourg City
# 97                                                 NaN              Katherine
# 98                                               Wiggo                  Ghent
# 99                                             Froomey                Nairobi
# 100  Lo Squalo (The Shark), 'il Roditore' (The Nibb...                Messina
# 101                                            Froomey                Nairobi
# 102                                            Froomey                Nairobi
# 103                                            Froomey                Nairobi
# 104                                                  G                Cardiff
# 105                                                NaN                 Bogotá
#
#     birth_country     nationality weight_lbs  year decade      speed
# 56        Belgium         Belgium      162.8  1970  1970s  35.589309
# 57        Belgium         Belgium      162.8  1971  1970s  37.290491
# 58        Belgium         Belgium      162.8  1972  1970s  35.516291
# 59          Spain           Spain      114.4  1973  1970s  33.407906
# 60        Belgium         Belgium      162.8  1974  1970s  35.241676
# 61         France          France        NaN  1975  1970s  34.906468
# 62        Belgium         Belgium      127.6  1976  1970s  34.518300
# 63         France          France        NaN  1977  1970s  35.419759
# 64         France          France      136.4  1978  1970s  36.084949
# 65         France          France      136.4  1979  1970s  36.513025
# 66    Netherlands     Netherlands      149.6  1980  1980s  35.144351
# 67         France          France      136.4  1981  1980s  38.960949
# 68         France          France      136.4  1982  1980s  38.059121
# 69         France          France      147.4  1983  1980s  36.230950
# 70         France          France      147.4  1984  1980s  35.882207
# 71         France          France      136.4  1985  1980s  36.232527
# 72            USA   United States      147.4  1986  1980s  37.020087
# 73        Ireland         Ireland      162.8  1987  1980s  36.644196
# 74          Spain           Spain      140.8  1988  1980s  38.903816
# 75            USA   United States      147.4  1989  1980s  37.481578
# 76            USA   United States      147.4  1990  1990s  38.623393
# 77          Spain           Spain      176.0  1991  1990s  38.743951
# 78          Spain           Spain      176.0  1992  1990s  39.504091
# 79          Spain           Spain      176.0  1993  1990s  38.706652
# 80          Spain           Spain      176.0  1994  1990s  38.381424
# 81          Spain           Spain      176.0  1995  1990s  39.191492
# 82        Denmark         Denmark      156.2  1996  1990s  39.237370
# 83        Germany         Germany      160.6  1997  1990s  39.299681
# 84          Italy           Italy      125.4  1998  1990s  41.743221
# 85            USA   United States      165.0  1999  1990s  40.278452
# 86            USA   United States      165.0  2000  2000s  39.566851
# 87            USA   United States      165.0  2001  2000s  40.073652
# 88            USA   United States      165.0  2002  2000s  39.860310
# 89            USA   United States      165.0  2003  2000s  40.950370
# 90            USA   United States      165.0  2004  2000s  40.561931
# 91            USA   United States      165.0  2005  2000s  41.657703
# 92          Spain           Spain      149.6  2006  2000s  40.780976
# 93          Spain           Spain      136.4  2007  2000s  39.227656
# 94          Spain           Spain      132.0  2008  2000s  40.497895
# 95          Spain           Spain      136.4  2009  2000s  40.310118
# 96     Luxembourg      Luxembourg      149.6  2010  2010s  39.590901
# 97      Australia       Australia      140.8  2011  2010s  39.788363
# 98        Belgium   Great Britain      151.8  2012  2010s  39.917916
# 99          Kenya   Great Britain      151.8  2013  2010s  40.553313
# 100         Italy           Italy      143.0  2014  2010s  40.679002
# 101         Kenya   Great Britain      151.8  2015  2010s  39.639943
# 102         Kenya   Great Britain      151.8  2016  2010s  39.616075
# 103         Kenya   Great Britain      151.8  2017  2010s  40.996606
# 104         Wales   Great Britain      156.2  2018  2010s  40.210384
# 105      Columbia        Colombia      132.0  2019  2010s  40.373719
#
# [50 rows x 23 columns]

# %% [markdown]
# #### AVERAGE WINNING SPEED BY DECADE

# %%
winners.groupby("decade")["speed"].mean()
# Out:
# decade
# 1900s    25.472096
# 1910s    25.869263
# 1920s    25.402801
# 1930s    30.302641
# 1940s    32.296398
# 1950s    34.302476
# 1960s    35.902913
# 1970s    35.448817
# 1980s    37.055978
# 1990s    39.370973
# 2000s    40.348746
# 2010s    40.136622
# Name: speed, dtype: float64

# %%
winners.dtypes
# Out:
# edition                   int64
# start_date       datetime64[ns]
# winner_name              object
# winner_team              object
# distance                float64
# time_overall            float64
# time_margin             float64
# stage_wins                int64
# stages_led                int64
# height                  float64
# weight                  float64
# age                       int64
# born                     object
# died                     object
# full_name                object
# nickname                 object
# birth_town               object
# birth_country            object
# nationality              object
# weight_lbs              float64
# year                      int64
# dtype: object

# %%
winners[["winner_name", "start_date"]].sort_values(by="start_date", ascending=False)
# Out:
#              winner_name start_date
# 105          Egan Bernal 2019-07-06
# 104       Geraint Thomas 2018-07-07
# 103         Chris Froome 2017-07-01
# 102         Chris Froome 2016-07-02
# 101         Chris Froome 2015-07-04
# ..                   ...        ...
# 4    Lucien Petit-Breton 1907-07-08
# 3           René Pottier 1906-07-04
# 2      Louis Trousselier 1905-07-09
# 1           Henri Cornet 1904-07-02
# 0          Maurice Garin 1903-07-01
#
# [106 rows x 2 columns]

# %%
winners["birth_country"].value_counts().head(5)
# Out:
# France     36
# Belgium    19
# Spain      12
# Italy      11
# USA        10
# Name: birth_country, dtype: int64

# %%
winners["nationality"].value_counts().head(5)
# Out:
#  France           36
#  Belgium          18
#  Spain            12
#  Italy            10
#  United States    10
# Name: nationality, dtype: int64
